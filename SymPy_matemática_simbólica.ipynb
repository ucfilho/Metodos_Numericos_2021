# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/Metodos_Numericos_2021/blob/main/SymPy_matem%C3%A1tica_simb%C3%B3lica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sympy import diff, sin, cos, exp, pi
from sympy.abc import x,y

# %%
expr=x*sin(x*x)+1
diff(expr,x)
# Out:
# 2*x**2*cos(x**2) + sin(x**2)

# %%
F1=x**2 - y + x*cos(pi*x)
F2=x*y + exp(y) - x**(-1.0)

# %%
diff(F1,x)
# Out:
# -pi*x*sin(pi*x) + 2*x + cos(pi*x)

# %%
diff(F1,y)
# Out:
# -1

# %%
diff(F2,x)
# Out:
# 1.0*x**(-2.0) + y

# %%
diff(F2,y)
# Out:
# x + exp(y)
